# %% [markdown]
# This little script untars uncompressed native (`.nat`) satellite image files downloaded from EUMETSAT.
#
# Set `SRC_PATH` to be the directory holding all the `.tar` files downloaded from EUMETSAT.
#
# Set `DST_PATH` to be the destination path.  This script will store data in a directory structure of the form `<year>/<month>/<day>/<hour>/<minute/` e.g. `2019/01/10/20/55`.
#
# Set `TMP_PATH` to a place which will be used to temporarily store the un-tarred `.nat` files before they are compressed and sorted.  For speed, use an SSD or RAM disk (although a spinning disk is also fine!)
#
# ## Requirements
#
# * Install [pbzip2](https://linux.die.net/man/1/pbzip2) (a parallel-processing version of bzip2).  On Ubuntu: `sudo apt install pbzip2`

# %%
import tarfile
import re
import os
import glob
from datetime import datetime
import subprocess
import shutil

# %%
PATH = '/storage/data/eumetsat/native/'

# The directory containing the tar files downloaded from EUMETSAT
SRC_PATH = os.path.join(PATH, 'testing')
TMP_PATH = '/home/jack/temp'
DST_PATH = os.path.join(PATH, 'sorted')
DEL_PATH = os.path.join(PATH, 'delete_me')  # The path where we put files ready to be deleted

# This is a list of the tar files which have already been processed.
# This is useful so that this script can re-start for where it left off,
# if needs be.
LIST_OF_COMPLETED_FILES = os.path.join(PATH, 'completed_files.txt')

# %% [markdown]
# In the code below, we use the term `full_filename` to refer to a filename including the full path, e.g. `/storage/data/eumetsat/native/auto_downloads/1354458-1-1of8.tar`
#
# The `base_filename` is the filename _without_ the path, e.g. `1354458-1-1of8.tar`

# %%
# Load list of completed files
if os.path.exists(LIST_OF_COMPLETED_FILES):
    with open(LIST_OF_COMPLETED_FILES, 'r') as fh:
        full_tar_filenames_completed = fh.readlines()
    full_tar_filenames_completed = [fname.strip() for fname in full_tar_filenames_completed]
else:
    full_tar_filenames_completed = []
    
full_tar_filenames_completed.sort()

# %%
full_tar_filenames_completed[:5]
# Out:
# ['/storage/data/eumetsat/native/auto_downloads/1354458-1-1of8.tar',
#  '/storage/data/eumetsat/native/auto_downloads/1354458-1-2of8.tar',
#  '/storage/data/eumetsat/native/auto_downloads/1354458-1-3of8.tar',
#  '/storage/data/eumetsat/native/auto_downloads/1354458-1-4of8.tar',
#  '/storage/data/eumetsat/native/auto_downloads/1354458-1-5of8.tar']

# %%
full_tar_filenames = glob.glob(os.path.join(SRC_PATH, '*.tar'))
full_tar_filenames.sort()

len(full_tar_filenames)
# Out:
# 102

# %%
full_tar_filenames[:5]
# Out:
# ['/storage/data/eumetsat/native/testing/1354464-1-1of8.tar',
#  '/storage/data/eumetsat/native/testing/1354464-1-2of8.tar',
#  '/storage/data/eumetsat/native/testing/1354464-1-3of8.tar',
#  '/storage/data/eumetsat/native/testing/1354464-1-4of8.tar',
#  '/storage/data/eumetsat/native/testing/1354464-1-5of8.tar']

# %%
# Remove files which have previously been completed
completed_base_filenames = [os.path.basename(filename) for filename in full_tar_filenames_completed]
full_tar_filenames_filtered = [
    full_tar_filename for full_tar_filename in full_tar_filenames 
    if os.path.basename(full_tar_filename) not in completed_base_filenames]
full_tar_filenames_filtered.sort()
n = len(full_tar_filenames_filtered)
n
# Out:
# 91

# %%
def get_datetime(inner_tar_name):
    p = re.compile('^MSG[23]-SEVI-MSG15-0100-NA-(\d*)\.')
    title_match = p.match(inner_tar_name)
    date_str = title_match.group(1)
    return datetime.strptime(date_str, "%Y%m%d%H%M%S")

# TODO: Logging
for i, full_tar_filename in enumerate(full_tar_filenames_filtered):
    print(i+1, 'of', n, '= {:.0%}'.format((i+1)/n), ' : ', full_tar_filename)
    base_tar_filename = os.path.basename(full_tar_filename)
    
    # Extract tar file to TMP_PATH/base_filename/
    new_tmp_path = os.path.join(TMP_PATH, os.path.splitext(base_tar_filename)[0])
    if not os.path.exists(new_tmp_path):
        os.makedirs(new_tmp_path)
    with tarfile.open(full_tar_filename) as tar:
        # `extractall` will throw a `ReadError: unexpected end of data` if the 
        # tar file is incomplete.
        tar.extractall(new_tmp_path)
        
    # Now compress & move each native file
    full_native_filenames = glob.glob(os.path.join(new_tmp_path, '*.nat'))
    print('Found', len(native_filenames), 'native files')
    # TODO: Check filesize of the native files?
    for full_native_filename in full_native_filenames:
        print('\r', full_native_filename, end='', flush=True)
        # TODO: Capture output of subprocess
        completed_process = subprocess.run(['pbzip2', '-5', full_native_filename])
        completed_process.check_returncode()
        base_native_filename = os.path.basename(full_native_filename)
        dt = get_datetime(base_native_filename)
        new_dst_path = os.path.join(DST_PATH, dt.strftime("%Y/%m/%d/%H/%M"))
        if not os.path.exists(new_dst_path):
            os.makedirs(new_dst_path)
        shutil.move(src=full_native_filename + '.bz2', dst=new_dst_path)
        
    # Tidy up
    os.rmdir(new_tmp_path)
    shutil.move(src=full_tar_filename, dst=DEL_PATH)

    with open(LIST_OF_COMPLETED_FILES, 'a') as fh:
        fh.write('{}\n'.format(full_tar_filename))

    print()
# Out:
# 1 of 91 = 1%  :  /storage/data/eumetsat/native/testing/1355708-1-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-1of8/MSG3-SEVI-MSG15-0100-NA-20190131050418.075000000Z-20190131050435-1355708-1.nat
# 2 of 91 = 2%  :  /storage/data/eumetsat/native/testing/1355708-1-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-2of8/MSG3-SEVI-MSG15-0100-NA-20190131073418.039000000Z-20190131073435-1355708-1.nat
# 3 of 91 = 3%  :  /storage/data/eumetsat/native/testing/1355708-1-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-3of8/MSG3-SEVI-MSG15-0100-NA-20190131085918.180000000Z-20190131085936-1355708-1.nat
# 4 of 91 = 4%  :  /storage/data/eumetsat/native/testing/1355708-1-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-4of8/MSG3-SEVI-MSG15-0100-NA-20190131105917.679000000Z-20190131105935-1355708-1.nat
# 5 of 91 = 5%  :  /storage/data/eumetsat/native/testing/1355708-1-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-5of8/MSG3-SEVI-MSG15-0100-NA-20190131125917.177000000Z-20190131125935-1355708-1.nat
# 6 of 91 = 7%  :  /storage/data/eumetsat/native/testing/1355708-1-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-6of8/MSG3-SEVI-MSG15-0100-NA-20190131155917.617000000Z-20190131155935-1355708-1.nat
# 7 of 91 = 8%  :  /storage/data/eumetsat/native/testing/1355708-1-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-1-7of8/MSG3-SEVI-MSG15-0100-NA-20190131173417.910000000Z-20190131173438-1355708-1.nat
# 8 of 91 = 9%  :  /storage/data/eumetsat/native/testing/1355708-1-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-1-8of8/MSG3-SEVI-MSG15-0100-NA-20190131201416.814000000Z-20190131201436-1355708-1.nat
# 9 of 91 = 10%  :  /storage/data/eumetsat/native/testing/1355708-10-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-1of8/MSG3-SEVI-MSG15-0100-NA-20190208180417.757000000Z-20190208180436-1355708-10.nat
# 10 of 91 = 11%  :  /storage/data/eumetsat/native/testing/1355708-10-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-2of8/MSG3-SEVI-MSG15-0100-NA-20190208195917.537000000Z-20190208195935-1355708-10.nat
# 11 of 91 = 12%  :  /storage/data/eumetsat/native/testing/1355708-10-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-3of8/MSG3-SEVI-MSG15-0100-NA-20190209041917.433000000Z-20190209041935-1355708-10.nat
# 12 of 91 = 13%  :  /storage/data/eumetsat/native/testing/1355708-10-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-4of8/MSG3-SEVI-MSG15-0100-NA-20190209053917.761000000Z-20190209053935-1355708-10.nat
# 13 of 91 = 14%  :  /storage/data/eumetsat/native/testing/1355708-10-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-5of8/MSG3-SEVI-MSG15-0100-NA-20190209084415.295000000Z-20190209084433-1355708-10.nat
# 14 of 91 = 15%  :  /storage/data/eumetsat/native/testing/1355708-10-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-6of8/MSG3-SEVI-MSG15-0100-NA-20190209115417.741000000Z-20190209115505-1355708-10.nat
# 15 of 91 = 16%  :  /storage/data/eumetsat/native/testing/1355708-10-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-10-7of8/MSG3-SEVI-MSG15-0100-NA-20190209133417.256000000Z-20190209133435-1355708-10.nat
# 16 of 91 = 18%  :  /storage/data/eumetsat/native/testing/1355708-10-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-10-8of8/MSG3-SEVI-MSG15-0100-NA-20190209145416.384000000Z-20190209145504-1355708-10.nat
# 17 of 91 = 19%  :  /storage/data/eumetsat/native/testing/1355708-11-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-1of8/MSG3-SEVI-MSG15-0100-NA-20190209161417.915000000Z-20190209161435-1355708-11.nat
# 18 of 91 = 20%  :  /storage/data/eumetsat/native/testing/1355708-11-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-2of8/MSG3-SEVI-MSG15-0100-NA-20190209180417.610000000Z-20190209180435-1355708-11.nat
# 19 of 91 = 21%  :  /storage/data/eumetsat/native/testing/1355708-11-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-3of8/MSG3-SEVI-MSG15-0100-NA-20190210032917.561000000Z-20190210032935-1355708-11.nat
# 20 of 91 = 22%  :  /storage/data/eumetsat/native/testing/1355708-11-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-4of8/MSG3-SEVI-MSG15-0100-NA-20190210052417.360000000Z-20190210052437-1355708-11.nat
# 21 of 91 = 23%  :  /storage/data/eumetsat/native/testing/1355708-11-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-5of8/MSG3-SEVI-MSG15-0100-NA-20190210090416.779000000Z-20190210090434-1355708-11.nat
# 22 of 91 = 24%  :  /storage/data/eumetsat/native/testing/1355708-11-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-6of8/MSG3-SEVI-MSG15-0100-NA-20190210092917.260000000Z-20190210092935-1355708-11.nat
# 23 of 91 = 25%  :  /storage/data/eumetsat/native/testing/1355708-11-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-11-7of8/MSG3-SEVI-MSG15-0100-NA-20190210125916.493000000Z-20190210125933-1355708-11.nat
# 24 of 91 = 26%  :  /storage/data/eumetsat/native/testing/1355708-11-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-11-8of8/MSG3-SEVI-MSG15-0100-NA-20190210142416.926000000Z-20190210142434-1355708-11.nat
# 25 of 91 = 27%  :  /storage/data/eumetsat/native/testing/1355708-12-1of3.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-12-1of3/MSG3-SEVI-MSG15-0100-NA-20190210160917.739000000Z-20190210160935-1355708-12.nat
# 26 of 91 = 29%  :  /storage/data/eumetsat/native/testing/1355708-12-2of3.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-12-2of3/MSG3-SEVI-MSG15-0100-NA-20190210171916.675000000Z-20190210171934-1355708-12.nat
# 27 of 91 = 30%  :  /storage/data/eumetsat/native/testing/1355708-12-3of3.tar
# Found 19 native files
#  /storage/data/eumetsat/native/temp/1355708-12-3of3/MSG3-SEVI-MSG15-0100-NA-20190210194918.342000000Z-20190210194936-1355708-12.nat
# 28 of 91 = 31%  :  /storage/data/eumetsat/native/testing/1355708-2-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-1of8/MSG3-SEVI-MSG15-0100-NA-20190201031417.402000000Z-20190201031435-1355708-2.nat
# 29 of 91 = 32%  :  /storage/data/eumetsat/native/testing/1355708-2-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-2of8/MSG3-SEVI-MSG15-0100-NA-20190201045916.660000000Z-20190201045935-1355708-2.nat
# 30 of 91 = 33%  :  /storage/data/eumetsat/native/testing/1355708-2-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-3of8/MSG3-SEVI-MSG15-0100-NA-20190201074418.081000000Z-20190201074436-1355708-2.nat
# 31 of 91 = 34%  :  /storage/data/eumetsat/native/testing/1355708-2-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-4of8/MSG3-SEVI-MSG15-0100-NA-20190201112918.063000000Z-20190201112936-1355708-2.nat
# 32 of 91 = 35%  :  /storage/data/eumetsat/native/testing/1355708-2-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-5of8/MSG3-SEVI-MSG15-0100-NA-20190201130917.253000000Z-20190201130935-1355708-2.nat
# 33 of 91 = 36%  :  /storage/data/eumetsat/native/testing/1355708-2-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-6of8/MSG3-SEVI-MSG15-0100-NA-20190201143415.000000000Z-20190201143433-1355708-2.nat
# 34 of 91 = 37%  :  /storage/data/eumetsat/native/testing/1355708-2-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-2-7of8/MSG3-SEVI-MSG15-0100-NA-20190201185917.998000000Z-20190201185936-1355708-2.nat
# 35 of 91 = 38%  :  /storage/data/eumetsat/native/testing/1355708-2-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-2-8of8/MSG3-SEVI-MSG15-0100-NA-20190201192417.190000000Z-20190201192435-1355708-2.nat
# 36 of 91 = 40%  :  /storage/data/eumetsat/native/testing/1355708-3-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-1of8/MSG3-SEVI-MSG15-0100-NA-20190201201916.854000000Z-20190201201934-1355708-3.nat
# 37 of 91 = 41%  :  /storage/data/eumetsat/native/testing/1355708-3-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-2of8/MSG3-SEVI-MSG15-0100-NA-20190202063918.269000000Z-20190202063935-1355708-3.nat
# 38 of 91 = 42%  :  /storage/data/eumetsat/native/testing/1355708-3-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-3of8/MSG3-SEVI-MSG15-0100-NA-20190202074918.187000000Z-20190202074935-1355708-3.nat
# 39 of 91 = 43%  :  /storage/data/eumetsat/native/testing/1355708-3-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-4of8/MSG3-SEVI-MSG15-0100-NA-20190202110916.582000000Z-20190202110934-1355708-3.nat
# 40 of 91 = 44%  :  /storage/data/eumetsat/native/testing/1355708-3-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-5of8/MSG3-SEVI-MSG15-0100-NA-20190202113917.063000000Z-20190202113935-1355708-3.nat
# 41 of 91 = 45%  :  /storage/data/eumetsat/native/testing/1355708-3-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-6of8/MSG3-SEVI-MSG15-0100-NA-20190202140918.264000000Z-20190202140935-1355708-3.nat
# 42 of 91 = 46%  :  /storage/data/eumetsat/native/testing/1355708-3-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-3-7of8/MSG3-SEVI-MSG15-0100-NA-20190202174918.164000000Z-20190202174937-1355708-3.nat
# 43 of 91 = 47%  :  /storage/data/eumetsat/native/testing/1355708-3-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-3-8of8/MSG3-SEVI-MSG15-0100-NA-20190202190918.231000000Z-20190202190936-1355708-3.nat
# 44 of 91 = 48%  :  /storage/data/eumetsat/native/testing/1355708-4-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-1of8/MSG3-SEVI-MSG15-0100-NA-20190202194415.178000000Z-20190202194434-1355708-4.nat
# 45 of 91 = 49%  :  /storage/data/eumetsat/native/testing/1355708-4-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-2of8/MSG3-SEVI-MSG15-0100-NA-20190203054915.186000000Z-20190203054933-1355708-4.nat
# 46 of 91 = 51%  :  /storage/data/eumetsat/native/testing/1355708-4-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-3of8/MSG3-SEVI-MSG15-0100-NA-20190203082917.756000000Z-20190203082936-1355708-4.nat
# 47 of 91 = 52%  :  /storage/data/eumetsat/native/testing/1355708-4-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-4of8/MSG3-SEVI-MSG15-0100-NA-20190203094417.760000000Z-20190203094435-1355708-4.nat
# 48 of 91 = 53%  :  /storage/data/eumetsat/native/testing/1355708-4-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-5of8/MSG3-SEVI-MSG15-0100-NA-20190203121417.770000000Z-20190203121435-1355708-4.nat
# 49 of 91 = 54%  :  /storage/data/eumetsat/native/testing/1355708-4-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-6of8/MSG3-SEVI-MSG15-0100-NA-20190203152916.093000000Z-20190203152934-1355708-4.nat
# 50 of 91 = 55%  :  /storage/data/eumetsat/native/testing/1355708-4-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-4-7of8/MSG3-SEVI-MSG15-0100-NA-20190203160916.733000000Z-20190203160934-1355708-4.nat
# 51 of 91 = 56%  :  /storage/data/eumetsat/native/testing/1355708-4-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-4-8of8/MSG3-SEVI-MSG15-0100-NA-20190203182917.767000000Z-20190203182935-1355708-4.nat
# 52 of 91 = 57%  :  /storage/data/eumetsat/native/testing/1355708-5-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-1of8/MSG3-SEVI-MSG15-0100-NA-20190203202916.069000000Z-20190203202934-1355708-5.nat
# 53 of 91 = 58%  :  /storage/data/eumetsat/native/testing/1355708-5-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-2of8/MSG3-SEVI-MSG15-0100-NA-20190204030917.639000000Z-20190204030935-1355708-5.nat
# 54 of 91 = 59%  :  /storage/data/eumetsat/native/testing/1355708-5-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-3of8/MSG3-SEVI-MSG15-0100-NA-20190204074417.250000000Z-20190204074435-1355708-5.nat
# 55 of 91 = 60%  :  /storage/data/eumetsat/native/testing/1355708-5-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-4of8/MSG3-SEVI-MSG15-0100-NA-20190204090417.338000000Z-20190204090435-1355708-5.nat
# 56 of 91 = 62%  :  /storage/data/eumetsat/native/testing/1355708-5-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-5of8/MSG3-SEVI-MSG15-0100-NA-20190204120416.638000000Z-20190204120434-1355708-5.nat
# 57 of 91 = 63%  :  /storage/data/eumetsat/native/testing/1355708-5-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-6of8/MSG3-SEVI-MSG15-0100-NA-20190204124917.365000000Z-20190204124935-1355708-5.nat
# 58 of 91 = 64%  :  /storage/data/eumetsat/native/testing/1355708-5-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-5-7of8/MSG3-SEVI-MSG15-0100-NA-20190204161918.343000000Z-20190204161935-1355708-5.nat
# 59 of 91 = 65%  :  /storage/data/eumetsat/native/testing/1355708-5-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-5-8of8/MSG3-SEVI-MSG15-0100-NA-20190204175917.541000000Z-20190204175935-1355708-5.nat
# 60 of 91 = 66%  :  /storage/data/eumetsat/native/testing/1355708-6-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-1of8/MSG3-SEVI-MSG15-0100-NA-20190204183418.101000000Z-20190204183436-1355708-6.nat
# 61 of 91 = 67%  :  /storage/data/eumetsat/native/testing/1355708-6-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-2of8/MSG3-SEVI-MSG15-0100-NA-20190205044917.842000000Z-20190205044935-1355708-6.nat
# 62 of 91 = 68%  :  /storage/data/eumetsat/native/testing/1355708-6-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-3of8/MSG3-SEVI-MSG15-0100-NA-20190205071917.755000000Z-20190205071935-1355708-6.nat
# 63 of 91 = 69%  :  /storage/data/eumetsat/native/testing/1355708-6-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-4of8/MSG2-SEVI-MSG15-0100-NA-20190205093918.809000000Z-20190205093938-1355708-6.nat
# 64 of 91 = 70%  :  /storage/data/eumetsat/native/testing/1355708-6-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-5of8/MSG2-SEVI-MSG15-0100-NA-20190205101416.901000000Z-20190205101435-1355708-6.nat
# 65 of 91 = 71%  :  /storage/data/eumetsat/native/testing/1355708-6-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-6of8/MSG2-SEVI-MSG15-0100-NA-20190205141415.987000000Z-20190205141435-1355708-6.nat
# 66 of 91 = 73%  :  /storage/data/eumetsat/native/testing/1355708-6-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-6-7of8/MSG2-SEVI-MSG15-0100-NA-20190205161417.934000000Z-20190205161437-1355708-6.nat
# 67 of 91 = 74%  :  /storage/data/eumetsat/native/testing/1355708-6-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-6-8of8/MSG2-SEVI-MSG15-0100-NA-20190205172919.285000000Z-20190205172937-1355708-6.nat
# 68 of 91 = 75%  :  /storage/data/eumetsat/native/testing/1355708-7-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-1of8/MSG2-SEVI-MSG15-0100-NA-20190205192417.218000000Z-20190205192436-1355708-7.nat
# 69 of 91 = 76%  :  /storage/data/eumetsat/native/testing/1355708-7-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-2of8/MSG2-SEVI-MSG15-0100-NA-20190205203915.506000000Z-20190205203934-1355708-7.nat
# 70 of 91 = 77%  :  /storage/data/eumetsat/native/testing/1355708-7-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-3of8/MSG2-SEVI-MSG15-0100-NA-20190206054419.511000000Z-20190206054438-1355708-7.nat
# 71 of 91 = 78%  :  /storage/data/eumetsat/native/testing/1355708-7-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-4of8/MSG2-SEVI-MSG15-0100-NA-20190206071917.372000000Z-20190206071936-1355708-7.nat
# 72 of 91 = 79%  :  /storage/data/eumetsat/native/testing/1355708-7-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-5of8/MSG2-SEVI-MSG15-0100-NA-20190206104419.462000000Z-20190206104438-1355708-7.nat
# 73 of 91 = 80%  :  /storage/data/eumetsat/native/testing/1355708-7-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-6of8/MSG2-SEVI-MSG15-0100-NA-20190206125916.867000000Z-20190206125935-1355708-7.nat
# 74 of 91 = 81%  :  /storage/data/eumetsat/native/testing/1355708-7-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-7-7of8/MSG2-SEVI-MSG15-0100-NA-20190206154416.238000000Z-20190206154434-1355708-7.nat
# 75 of 91 = 82%  :  /storage/data/eumetsat/native/testing/1355708-7-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-7-8of8/MSG2-SEVI-MSG15-0100-NA-20190206164919.922000000Z-20190206164940-1355708-7.nat
# 76 of 91 = 84%  :  /storage/data/eumetsat/native/testing/1355708-8-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-1of8/MSG2-SEVI-MSG15-0100-NA-20190206191916.606000000Z-20190206191937-1355708-8.nat
# 77 of 91 = 85%  :  /storage/data/eumetsat/native/testing/1355708-8-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-2of8/MSG2-SEVI-MSG15-0100-NA-20190207034415.614000000Z-20190207034433-1355708-8.nat
# 78 of 91 = 86%  :  /storage/data/eumetsat/native/testing/1355708-8-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-3of8/MSG2-SEVI-MSG15-0100-NA-20190207053920.708000000Z-20190207053939-1355708-8.nat
# 79 of 91 = 87%  :  /storage/data/eumetsat/native/testing/1355708-8-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-4of8/MSG2-SEVI-MSG15-0100-NA-20190207082919.769000000Z-20190207082938-1355708-8.nat
# 80 of 91 = 88%  :  /storage/data/eumetsat/native/testing/1355708-8-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-5of8/MSG3-SEVI-MSG15-0100-NA-20190207095918.392000000Z-20190207095936-1355708-8.nat
# 81 of 91 = 89%  :  /storage/data/eumetsat/native/testing/1355708-8-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-6of8/MSG3-SEVI-MSG15-0100-NA-20190207121917.451000000Z-20190207121935-1355708-8.nat
# 82 of 91 = 90%  :  /storage/data/eumetsat/native/testing/1355708-8-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-8-7of8/MSG3-SEVI-MSG15-0100-NA-20190207140917.141000000Z-20190207140935-1355708-8.nat
# 83 of 91 = 91%  :  /storage/data/eumetsat/native/testing/1355708-8-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-8-8of8/MSG3-SEVI-MSG15-0100-NA-20190207160917.017000000Z-20190207160934-1355708-8.nat
# 84 of 91 = 92%  :  /storage/data/eumetsat/native/testing/1355708-9-1of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-1of8/MSG3-SEVI-MSG15-0100-NA-20190207162917.397000000Z-20190207162934-1355708-9.nat
# 85 of 91 = 93%  :  /storage/data/eumetsat/native/testing/1355708-9-2of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-2of8/MSG3-SEVI-MSG15-0100-NA-20190207204917.510000000Z-20190207204935-1355708-9.nat
# 86 of 91 = 95%  :  /storage/data/eumetsat/native/testing/1355708-9-3of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-3of8/MSG3-SEVI-MSG15-0100-NA-20190208035417.151000000Z-20190208035504-1355708-9.nat
# 87 of 91 = 96%  :  /storage/data/eumetsat/native/testing/1355708-9-4of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-4of8/MSG3-SEVI-MSG15-0100-NA-20190208054418.045000000Z-20190208054435-1355708-9.nat
# 88 of 91 = 97%  :  /storage/data/eumetsat/native/testing/1355708-9-5of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-5of8/MSG3-SEVI-MSG15-0100-NA-20190208092417.441000000Z-20190208092436-1355708-9.nat
# 89 of 91 = 98%  :  /storage/data/eumetsat/native/testing/1355708-9-6of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-6of8/MSG3-SEVI-MSG15-0100-NA-20190208113917.621000000Z-20190208113935-1355708-9.nat
# 90 of 91 = 99%  :  /storage/data/eumetsat/native/testing/1355708-9-7of8.tar
# Found 29 native files
#  /storage/data/eumetsat/native/temp/1355708-9-7of8/MSG3-SEVI-MSG15-0100-NA-20190208133917.513000000Z-20190208133935-1355708-9.nat
# 91 of 91 = 100%  :  /storage/data/eumetsat/native/testing/1355708-9-8of8.tar
# Found 6 native files
#  /storage/data/eumetsat/native/temp/1355708-9-8of8/MSG3-SEVI-MSG15-0100-NA-20190208152417.115000000Z-20190208152434-1355708-9.nat
